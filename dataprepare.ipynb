# %%
import pandas as pd

# Load the CSV
df = pd.read_csv('survey_data_updated 5.csv')

# Ensure the 'LanguageHaveWorkedWith' column exists
    # Split languages into a list
df['LanguageList'] = df['LanguageHaveWorkedWith'].str.split(';')

# Explode the list into separate rows
df_exploded = df.explode('LanguageList')

# Optionally drop the original LanguageHaveWorkedWith column
df_exploded.drop(columns=['LanguageHaveWorkedWith'], inplace=True)

# Rename LanguageList to LanguageHaveWorkedWith
df_exploded.rename(columns={'LanguageList': 'LanguageHaveWorkedWith'}, inplace=True)



    # Split languages into a list
df['LanguageList'] = df['DatabaseHaveWorkedWith'].str.split(';')

# Explode the list into separate rows
df_exploded = df.explode('LanguageList')

# Optionally drop the original LanguageHaveWorkedWith column
df_exploded.drop(columns=['DatabaseHaveWorkedWith'], inplace=True)

# Rename LanguageList to LanguageHaveWorkedWith
df_exploded.rename(columns={'LanguageList': 'DatabaseHaveWorkedWith'}, inplace=True)


# Split languages into a list
df['LanguageList'] = df['PlatformHaveWorkedWith'].str.split(';')

# Explode the list into separate rows
df_exploded = df.explode('LanguageList')

# Optionally drop the original LanguageHaveWorkedWith column
df_exploded.drop(columns=['PlatformHaveWorkedWith'], inplace=True)

# Rename LanguageList to LanguageHaveWorkedWith
df_exploded.rename(columns={'LanguageList': 'PlatformHaveWorkedWith'}, inplace=True)

    # Split languages into a list
df['LanguageList'] = df['WebFrameHaveWorkedWith'].str.split(';')

# Explode the list into separate rows
df_exploded = df.explode('LanguageList')

# Optionally drop the original LanguageHaveWorkedWith column
df_exploded.drop(columns=['WebFrameHaveWorkedWith'], inplace=True)

# Rename LanguageList to LanguageHaveWorkedWith
df_exploded.rename(columns={'LanguageList': 'WebFrameHaveWorkedWith'}, inplace=True)

    
########################################


# Split languages into a list
df['LanguageList'] = df['LanguageWantToWorkWith'].str.split(';')

# Explode the list into separate rows
df_exploded = df.explode('LanguageList')

# Optionally drop the original LanguageHaveWorkedWith column
df_exploded.drop(columns=['LanguageWantToWorkWith'], inplace=True)

# Rename LanguageList to LanguageHaveWorkedWith
df_exploded.rename(columns={'LanguageList': 'LanguageWantToWorkWith'}, inplace=True)



# Split languages into a list
df['LanguageList'] = df['DatabaseWantToWorkWith'].str.split(';')

# Explode the list into separate rows
df_exploded = df.explode('LanguageList')

# Optionally drop the original LanguageHaveWorkedWith column
df_exploded.drop(columns=['DatabaseWantToWorkWith'], inplace=True)

# Rename LanguageList to LanguageHaveWorkedWith
df_exploded.rename(columns={'LanguageList': 'DatabaseWantToWorkWith'}, inplace=True)



# Split languages into a list
df['LanguageList'] = df['PlatformWantToWorkWith'].str.split(';')

# Explode the list into separate rows
df_exploded = df.explode('LanguageList')

# Optionally drop the original LanguageHaveWorkedWith column
df_exploded.drop(columns=['PlatformWantToWorkWith'], inplace=True)

# Rename LanguageList to LanguageHaveWorkedWith
df_exploded.rename(columns={'LanguageList': 'PlatformWantToWorkWith'}, inplace=True)


# Split languages into a list
df['LanguageList'] = df['WebframeWantToWorkWith'].str.split(';')

# Explode the list into separate rows
df_exploded = df.explode('LanguageList')

# Optionally drop the original LanguageHaveWorkedWith column
df_exploded.drop(columns=['WebframeWantToWorkWith'], inplace=True)

# Rename LanguageList to LanguageHaveWorkedWith
df_exploded.rename(columns={'LanguageList': 'WebframeWantToWorkWith'}, inplace=True)



df_exploded.to_csv('/mnt/data/survey_data_prepared_for_cognos.csv', index=False)
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)
# 0    Bash/Shell (all shells)
# 0                         Go
# 0                   HTML/CSS
# 0                       Java
# 0                 JavaScript
# Name: LanguageHaveWorkedWith, dtype: object
